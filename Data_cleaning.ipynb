# %%
import pandas as pd
import numpy as np

# %%
#importing GDP

GDP = pd.read_csv('data/GDP.csv', engine='python')

# %%
#clean first 5 rows, non-relevant information

GDP=GDP.iloc[4:]

# %%
#columns

GDP.columns
# Out:
# Index(['ï»¿Data Source', 'World Development Indicators', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
# ...

# %%
GDP.columns

GDPdrop=['Unnamed: 2','Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7','Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12','Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16','Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20','Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24','Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28','Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32','Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36','Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40','Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44','Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48','Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52','Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56','Unnamed: 57','Unnamed: 58' ]

# %%
GDP=GDP.drop(GDPdrop, axis=1)

#check it was successful

GDP
# Out:
#     ï»¿Data Source World Development Indicators   Unnamed: 59   Unnamed: 60  \
# 4            Aruba                          ABW  2.919553e+09  2.965922e+09
# 5      Afghanistan                          AFG  1.990711e+10  1.936264e+10
# 6           Angola                          AGO  1.161940e+11  1.011240e+11
# 7          Albania                          ALB  1.138685e+10  1.186120e+10
# 8          Andorra                          AND  2.789870e+09  2.896679e+09
# ..             ...                          ...           ...           ...
# 263         Kosovo                          XKX  6.442916e+09  6.719172e+09
# 264    Yemen, Rep.                          YEM  3.697620e+10  2.808468e+10
# 265   South Africa                          ZAF  3.176210e+11  2.963570e+11
# 266         Zambia                          ZMB  2.124335e+10  2.095476e+10
# 267       Zimbabwe                          ZWE  1.996312e+10  2.054868e+10
#
#       Unnamed: 61   Unnamed: 62   Unnamed: 63
# ...

# %%
#replace NAN

GDP=GDP.fillna(0)

# %%
# rename

GDP=GDP.rename(columns={'ï»¿Data Source':'Country', 'World Development Indicators':'Country_code','Unnamed: 59':'GDP US$ 2015', 'Unnamed: 60':'GDP US$ 2016','Unnamed: 61':'GDP US$ 2017', 'Unnamed: 62':'GDP US$ 2018', 'Unnamed: 63':'GDP US$ 2019'})

# %%
GDP.reset_index(drop=True, inplace=True)

# %%
GDP
# Out:
#           Country Country_code  GDP US$ 2015  GDP US$ 2016  GDP US$ 2017  \
# 0           Aruba          ABW  2.919553e+09  2.965922e+09  3.056425e+09
# 1     Afghanistan          AFG  1.990711e+10  1.936264e+10  2.019176e+10
# 2          Angola          AGO  1.161940e+11  1.011240e+11  1.221240e+11
# 3         Albania          ALB  1.138685e+10  1.186120e+10  1.301969e+10
# 4         Andorra          AND  2.789870e+09  2.896679e+09  3.000181e+09
# ..            ...          ...           ...           ...           ...
# 259        Kosovo          XKX  6.442916e+09  6.719172e+09  7.245707e+09
# 260   Yemen, Rep.          YEM  3.697620e+10  2.808468e+10  2.456133e+10
# 261  South Africa          ZAF  3.176210e+11  2.963570e+11  3.495540e+11
# 262        Zambia          ZMB  2.124335e+10  2.095476e+10  2.586814e+10
# 263      Zimbabwe          ZWE  1.996312e+10  2.054868e+10  2.204090e+10
#
#      GDP US$ 2018  GDP US$ 2019
# 0    0.000000e+00  0.000000e+00
# ...

# %%
#importing proportion of women in national parliments

women = pd.read_excel('data/government.xls')
women
# Out:
#            Data Source World Development Indicators  \
# 0    Last Updated Date          2020-07-01 00:00:00
# 1                  NaN                          NaN
# 2         Country Name                 Country Code
# 3                Aruba                          ABW
# 4          Afghanistan                          AFG
# ..                 ...                          ...
# 262             Kosovo                          XKX
# 263        Yemen, Rep.                          YEM
# 264       South Africa                          ZAF
# 265             Zambia                          ZMB
# 266           Zimbabwe                          ZWE
#
#                                             Unnamed: 2      Unnamed: 3  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                       Indicator Name  Indicator Code
# ...

# %%
#clean first rows, non-relevant information

women=women.iloc[3:]

# %%
#columns

women.columns
# Out:
# Index(['Data Source', 'World Development Indicators', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
# ...

# %%
#columns to drop women

womendrop=['Unnamed: 2','Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7','Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12','Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16','Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20','Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24','Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28','Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32','Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36','Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40','Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44','Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48','Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52','Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56','Unnamed: 57', 'Unnamed: 58']

# %%
women=women.drop(womendrop, axis=1)

#check it was successful

women
# Out:
#       Data Source World Development Indicators  Unnamed: 59  Unnamed: 60  \
# 3           Aruba                          ABW          NaN          NaN
# 4     Afghanistan                          AFG    27.710843    27.710843
# 5          Angola                          AGO    36.818182    36.818182
# 6         Albania                          ALB    20.714286    22.857143
# 7         Andorra                          AND    39.285714    32.142857
# ..            ...                          ...          ...          ...
# 262        Kosovo                          XKX          NaN          NaN
# 263   Yemen, Rep.                          YEM     0.000000     0.000000
# 264  South Africa                          ZAF    42.000000    42.000000
# 265        Zambia                          ZMB    12.658228    17.964072
# 266      Zimbabwe                          ZWE    31.481481    31.481481
#
#      Unnamed: 61  Unnamed: 62  Unnamed: 63
# 3            NaN          NaN          NaN
# ...

# %%
#replace NAN

women=women.fillna(0)

# %%
# rename

women=women.rename(columns={'Data Source':'Country', 'World Development Indicators':'Country_code', 'Unnamed: 59':'% women in national parliaments 2015','Unnamed: 60':'% women in national parliaments 2016','Unnamed: 61':'% women in national parliaments 2017','Unnamed: 62':'% women in national parliaments 2018','Unnamed: 63':'% women in national parliaments 2019'})

# %%
women
# Out:
#           Country Country_code  % women in national parliaments 2015  \
# 3           Aruba          ABW                              0.000000
# 4     Afghanistan          AFG                             27.710843
# 5          Angola          AGO                             36.818182
# 6         Albania          ALB                             20.714286
# 7         Andorra          AND                             39.285714
# ..            ...          ...                                   ...
# 262        Kosovo          XKX                              0.000000
# 263   Yemen, Rep.          YEM                              0.000000
# 264  South Africa          ZAF                             42.000000
# 265        Zambia          ZMB                             12.658228
# 266      Zimbabwe          ZWE                             31.481481
#
#      % women in national parliaments 2016  \
# 3                                0.000000
# 4                               27.710843
# ...

# %%
women.reset_index(drop=True, inplace=True)

# %%
women
# Out:
#           Country Country_code  % women in national parliaments 2015  \
# 0           Aruba          ABW                              0.000000
# 1     Afghanistan          AFG                             27.710843
# 2          Angola          AGO                             36.818182
# 3         Albania          ALB                             20.714286
# 4         Andorra          AND                             39.285714
# ..            ...          ...                                   ...
# 259        Kosovo          XKX                              0.000000
# 260   Yemen, Rep.          YEM                              0.000000
# 261  South Africa          ZAF                             42.000000
# 262        Zambia          ZMB                             12.658228
# 263      Zimbabwe          ZWE                             31.481481
#
#      % women in national parliaments 2016  \
# 0                                0.000000
# 1                               27.710843
# ...

# %%
#merge

tableau_data=GDP.merge(women, left_on='Country', right_on='Country')

tableau_data
# Out:
#           Country Country_code_x  GDP US$ 2015  GDP US$ 2016  GDP US$ 2017  \
# 0           Aruba            ABW  2.919553e+09  2.965922e+09  3.056425e+09
# 1     Afghanistan            AFG  1.990711e+10  1.936264e+10  2.019176e+10
# 2          Angola            AGO  1.161940e+11  1.011240e+11  1.221240e+11
# 3         Albania            ALB  1.138685e+10  1.186120e+10  1.301969e+10
# 4         Andorra            AND  2.789870e+09  2.896679e+09  3.000181e+09
# ..            ...            ...           ...           ...           ...
# 258        Kosovo            XKX  6.442916e+09  6.719172e+09  7.245707e+09
# 259   Yemen, Rep.            YEM  3.697620e+10  2.808468e+10  2.456133e+10
# 260  South Africa            ZAF  3.176210e+11  2.963570e+11  3.495540e+11
# 261        Zambia            ZMB  2.124335e+10  2.095476e+10  2.586814e+10
# 262      Zimbabwe            ZWE  1.996312e+10  2.054868e+10  2.204090e+10
#
#      GDP US$ 2018  GDP US$ 2019 Country_code_y  \
# ...

# %%
tableau_data.columns
# Out:
# Index(['Country', 'Country_code_x', 'GDP US$ 2015', 'GDP US$ 2016',
#        'GDP US$ 2017', 'GDP US$ 2018', 'GDP US$ 2019', 'Country_code_y',
#        '% women in national parliaments 2015',
#        '% women in national parliaments 2016',
#        '% women in national parliaments 2017',
#        '% women in national parliaments 2018',
#        '% women in national parliaments 2019'],
#       dtype='object')

# %%
tableau_data=tableau_data.drop(columns=['Country_code_x', 'Country_code_y'], axis=1)

# %%
tableau_data
# Out:
#           Country  GDP US$ 2015  GDP US$ 2016  GDP US$ 2017  GDP US$ 2018  \
# 0           Aruba  2.919553e+09  2.965922e+09  3.056425e+09  0.000000e+00
# 1     Afghanistan  1.990711e+10  1.936264e+10  2.019176e+10  1.948438e+10
# 2          Angola  1.161940e+11  1.011240e+11  1.221240e+11  1.013530e+11
# 3         Albania  1.138685e+10  1.186120e+10  1.301969e+10  1.514702e+10
# 4         Andorra  2.789870e+09  2.896679e+09  3.000181e+09  3.218316e+09
# ..            ...           ...           ...           ...           ...
# 258        Kosovo  6.442916e+09  6.719172e+09  7.245707e+09  7.942962e+09
# 259   Yemen, Rep.  3.697620e+10  2.808468e+10  2.456133e+10  2.759126e+10
# 260  South Africa  3.176210e+11  2.963570e+11  3.495540e+11  3.682890e+11
# 261        Zambia  2.124335e+10  2.095476e+10  2.586814e+10  2.700524e+10
# 262      Zimbabwe  1.996312e+10  2.054868e+10  2.204090e+10  2.431156e+10
#
#      GDP US$ 2019  % women in national parliaments 2015  \
# ...

# %%
tableau_data = tableau_data.to_csv('tableau_data.csv', index=False)
